# %%
# %pylab inline
import pandas
import sys
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path += ['/home/nath/Projects/challenge-cfm/python/']

# %%
import cooking_tools
from imp import reload
reload(cooking_tools)
from cooking_tools import *

# %%
test_data = pandas.read_csv('/home/nath/Projects/challenge-cfm/data/testing_input.csv', usecols=['nb_trade', 'offset', 'ID'])

# %%
nb_trade = get_data(test_data, 'nb_trade', 0)

# %%
plt.plot(nb_trade[:4679])

# %%
test_data['time'] = get_time(test_data)

# %%
get_data(test_data, ['time', 'nb_trade'], 0).iloc[:25*4679].groupby('time').sum().plot(figsize=(10,10))
get_data(test_data, ['time', 'nb_trade'], 0).iloc[100*4679:125*4679].groupby('time').sum().plot(figsize=(10,10))

# %%
for i in range(12):
    get_data(test_data, ['time', 'nb_trade'], 0).iloc[i*10*4679:(i+1)*10*4679].groupby('time').sum().plot(figsize=(10,10))

# %%
training_data = pandas.read_csv('/home/nath/Projects/challenge-cfm/data/training_input.csv', usecols=['nb_trade', 'offset', 'ID'])

# %%
training_data['time'] = get_time(training_data)

# %%
for i in range(12):
    get_data(training_data, ['time', 'nb_trade'], 0).iloc[i*10*4679:(i+1)*10*4679].groupby('time').sum().plot(figsize=(10,10))

# %%
for i in range(10):
    get_data(training_data, ['time', 'nb_trade'], 0).iloc[(10+i)*4679:(i+11)*4679].groupby('time').sum().plot(figsize=(10,10))
