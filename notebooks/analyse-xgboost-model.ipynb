# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import xgboost as xgb

# %%
bst = xgb.Booster({'nthread': 4})

# %%
bst.load_model('/home/nath/Projects/challenge-cfm/ubuntu@52.58.178.209/results/xgboost.model')

# %%
bst.dump_model('/tmp/test', '/home/nath/Projects/challenge-cfm/ubuntu@52.58.178.209/results/fmap.txt', with_stats=True)

# %%
thresholds = ! grep time /tmp/test | sed -e 's@.*time<\(.*\)].*@\1@'

# %%
len(thresholds)
# Out:
# 604

# %%
plt.figure(figsize=(10,10))
plt.plot(thresholds, [0]*604, 'ro')

# %%
a = !grep time /tmp/test | sed -e 's@.*time<\(.*\)].*gain=\(.*\),cover.*@\1,\2@'

# %%
thresholds = [float(x.split(',')[0]) for x in a]

# %%
gain = [float(x.split(',')[1]) for x in a]

# %%
plt.figure(figsize=(10,10))
plt.plot(thresholds, gain, 'ro')
