# %%
import pandas
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train = pandas.read_csv('../data/testing_input.csv', usecols=['bid_1', 'nb_trade', 'offset', 'bid_size_1'])

# %%
nb_trade = train.loc[train['offset']==0, 'nb_trade'].values

# %%
bid_diff = train.loc[train['offset']==0, 'bid_1'].diff().values

# %%
bid_diff[0]=0

# %%
plt.figure(figsize=(10,10))
nb_trade_mean = nb_trade[:125*4679].reshape((-1, 4679)).mean(axis=0)
bid_diff_mean = np.abs(bid_diff[:125*4679]).reshape((-1, 4679)).mean(axis=0)
bid_size = train.loc[train['offset']==0, 'bid_size_1'].values[:125*4679].reshape((-1, 4679)).mean(axis=0)
plt.plot(nb_trade_mean/np.max(nb_trade_mean))
plt.plot(bid_diff_mean/np.max(bid_diff_mean))
plt.plot(bid_size/np.max(bid_size))
for x in range(20):
    plt.axvline(4679/20*x)
