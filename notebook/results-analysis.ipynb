# %%
# %pylab inline
import pandas
from scipy.stats import gaussian_kde
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
RESULTSDIR = '/home/nath/Projects/challenge-cfm/ubuntu@52.58.180.162/results/'

# %% [markdown]
# ## Probas

# %%
probas = pandas.read_csv(RESULTSDIR + 'probas.csv')

# %%
probas.head()
# Out:
#    ID    PROBAS
# 0   1  0.579100
# 1   2  0.034864
# 2   3  0.035516
# 3   4  0.028584
# 4   5  0.026450

# %%
range_ = np.linspace(0, 1, 100)
plt.plot(range_, gaussian_kde(probas['PROBAS'])(range_))

# %%
1-(probas['PROBAS'] > 0.5).mean()
# Out:
# 0.75869826213567437

# %% [markdown]
# ## Features scores

# %%
fscores = pandas.read_csv(RESULTSDIR + 'fscores.txt')[['feature', 'fscore']]

# %%
fscores.set_index('feature', drop=True).sort_values(by='fscore').plot(kind='bar', figsize=(15, 15))

# %%
fscores.sort_values(by='fscore')['feature'].values[:10]
# Out:
# array(['bid_entry_1_epoch_high_low', 'bid_entry_2_epoch_std',
#        'bid_size_2_epoch_high_low', 'ask_entry_1_epoch_high_low',
#        'bid_open_close_10', 'bid_epoch_high_low', 'ask_entry_2_epoch_std',
#        'ask_size_2_epoch_high_low', 'bid_high_low_10',
#        'bid_sqentry_1_epoch_high_low'], dtype=object)
