# %%
# %pylab inline
import pandas
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
output=pandas.read_csv('data/challenge_output_data_training_file_prediction_of_trading_activity_within_the_order_book.csv', sep=';')

# %%
output.head()
# Out:
#    ID  TARGET
# 0   1       1
# 1   2       0
# 2   3       1
# 3   4       0
# 4   5       0

# %%
plt.figure(figsize=(10,10))
pandas.tools.plotting.autocorrelation_plot(output.loc[:1000, 'TARGET'])
